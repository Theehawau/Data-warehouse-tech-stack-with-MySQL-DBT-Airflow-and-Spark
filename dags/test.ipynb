# %%
import pandas as pd
import json

# %%
data = pd.read_csv('station_summary.csv')

# %%
data.head()
# Out:
#        ID  flow_99  flow_max  flow_median  flow_total   n_obs
# 0  313979     50.0      71.0         24.0  18447830.0  806622
# 1  313980     11.0      25.0          1.0   1618489.0  806622
# 2  313981     14.0      28.0          3.0   2916088.0  806622
# 3  314013     48.0      68.0         22.0  17301107.0  806548
# 4  314014     10.0      19.0          1.0   1522494.0  806548

# %%
li = list(data.columns)

# %%
result = list(data.to_records(index=False))
result
# Out:
# [(313979, 50., 71., 24., 18447830., 806622),
#  (313980, 11., 25., 1., 1618489., 806622),
#  (313981, 14., 28., 3., 2916088., 806622),
#  (314013, 48., 68., 22., 17301107., 806548),
#  (314014, 10., 19., 1., 1522494., 806548),
#  (314015, 0., 0., 0., 0., 806548),
#  (314025, 52., 72., 24., 18948991., 806522),
#  (314026, 6., 15., 1., 1069189., 806522),
#  (314548, 53., 110., 26., 19727734., 803427),
#  (314549, 14., 34., 1., 1821222., 803428),
#  (316773, 50., 102., 24., 17178088., 746685),
#  (316778, 32., 55., 15., 10807916., 746685),
#  (316783, 54., 76., 36., 2117604., 59948),
#  (316788, 38., 49., 23., 1370040., 59948),
#  (318017, 0., 0., 0., 0., 370938),
#  (318022, 0., 0., 0., 0., 371723),
#  (318052, 52., 66., 29., 17922124., 674239),
#  (318053, 54., 70., 28., 17846420., 674239),
#  (318054, 4., 14., 0., 433020., 674245),
#  (318055, 12., 18., 0., 1079760., 674239),
#  (318067, 64., 204., 21., 14556545., 709811),
#  (318068, 45., 62., 21., 14734600., 709811),
# ...

# %%
val = []
for _, row in data.iterrows():
    i = ()
    val.append((f"""({row[0]},{row[1]},{row[2]},{row[3]},{row[4]},{row[5]}) """))
val
# Out:
# [('(',
#   '3',
#   '1',
#   '3',
#   '9',
#   '7',
#   '9',
#   '.',
#   '0',
#   ',',
#   '5',
#   '0',
#   '.',
#   '0',
#   ',',
#   '7',
#   '1',
#   '.',
#   '0',
#   ',',
#   '2',
#   '4',
#   '.',
#   '0',
#   ',',
#   '1',
#   '8',
#   '4',
#   '4',
#   '7',
#   '8',
#   '3',
#   '0',
#   '.',
#   '0',
#   ',',
#   '8',
#   '0',
#   '6',
#   '6',
#   '2',
#   '2',
#   '.',
#   '0',
#   ')',
#   ' '),
#  ('(',
#   '3',
#   '1',
#   '3',
#   '9',
#   '8',
#   '0',
#   '.',
#   '0',
#   ',',
#   '1',
#   '1',
#   '.',
#   '0',
#   ',',
#   '2',
#   '5',
#   '.',
#   '0',
#   ',',
#   '1',
#   '.',
#   '0',
#   ',',
#   '1',
#   '6',
#   '1',
#   '8',
#   '4',
#   '8',
#   '9',
#   '.',
#   '0',
#   ',',
#   '8',
#   '0',
#   '6',
#   '6',
#   '2',
#   '2',
#   '.',
#   '0',
#   ')',
#   ' '),
#  ('(',
#   '3',
#   '1',
#   '3',
#   '9',
#   '8',
#   '1',
#   '.',
#   '0',
#   ',',
#   '1',
#   '4',
#   '.',
#   '0',
#   ',',
#   '2',
#   '8',
#   '.',
#   '0',
#   ',',
# ...

# %%
val
# Out:
# ['(313979.0,50.0,71.0,24.0,18447830.0,806622.0) ',
#  '(313980.0,11.0,25.0,1.0,1618489.0,806622.0) ',
#  '(313981.0,14.0,28.0,3.0,2916088.0,806622.0) ',
#  '(314013.0,48.0,68.0,22.0,17301107.0,806548.0) ',
#  '(314014.0,10.0,19.0,1.0,1522494.0,806548.0) ',
#  '(314015.0,0.0,0.0,0.0,0.0,806548.0) ',
#  '(314025.0,52.0,72.0,24.0,18948991.0,806522.0) ',
#  '(314026.0,6.0,15.0,1.0,1069189.0,806522.0) ',
#  '(314548.0,53.0,110.0,26.0,19727734.0,803427.0) ',
#  '(314549.0,14.0,34.0,1.0,1821222.0,803428.0) ',
#  '(316773.0,50.0,102.0,24.0,17178088.0,746685.0) ',
#  '(316778.0,32.0,55.0,15.0,10807916.0,746685.0) ',
#  '(316783.0,54.0,76.0,36.0,2117604.0,59948.0) ',
#  '(316788.0,38.0,49.0,23.0,1370040.0,59948.0) ',
#  '(318017.0,0.0,0.0,0.0,0.0,370938.0) ',
#  '(318022.0,0.0,0.0,0.0,0.0,371723.0) ',
#  '(318052.0,52.0,66.0,29.0,17922124.0,674239.0) ',
#  '(318053.0,54.0,70.0,28.0,17846420.0,674239.0) ',
#  '(318054.0,4.0,14.0,0.0,433020.0,674245.0) ',
# ...

# %%
variable_1 = "HELLO"
variable_2 = "ADIOS"
varlist = [variable_1, variable_2]
(tuple(varlist),)
# Out:
# (('HELLO', 'ADIOS'),)

# %%
param = [item for item in varlist]
','.join(varlist)
# Out:
# 'HELLO,ADIOS'

# %%
json.dumps(varlist)
# Out:
# '["HELLO", "ADIOS"]'

# %%
sql = "INSERT INTO customers (name, address) VALUES "
val = [
  ('Peter', 'Lowstreet 4'),
  ('Amy', 'Apple st 652'),
  ('Hannah', 'Mountain 21'),
  ('Michael', 'Valley 345'),
  ('Sandy', 'Ocean blvd 2'),
  ('Betty', 'Green Grass 1'),
  ('Richard', 'Sky st 331'),
  ('Susan', 'One way 98'),
  ('Vicky', 'Yellow Garden 2'),
  ('Ben', 'Park Lane 38'),
  ('William', 'Central st 954'),
  ('Chuck', 'Main Road 989'),
  ('Viola', 'Sideway 1633')
]

sql + val
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4ec1b4b19c17> in <module>
#      16 ]
#      17
# ---> 18 sql + val
#
# TypeError: can only concatenate str (not "list") to str

# %%
st = sql + str(val).replace('[','').replace(']','')

# %%
f = open ('test.sql', 'a') 
f.write(st)
f.write(';')
f.close()

# %%
f = open ('test.sql', 'a') 
f.write("""INSERT INTO stations ('ID', 'flow_99', 'flow_max', 'flow_median', 'flow_total', 'n_obs')
            VALUES \n """)
for _, row in data.iterrows():
    string = f"""({row[0]},{row[1]},{row[2]},{row[3]},{row[4]},{row[5]}),\n 
            """
    f.write(string)
f.write(';')
f.close()

# %%
import os

CUR_DIR = os.path.abspath(os.path.dirname(__file__))
CUR_DIR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6902a5dd1be8> in <module>
#       1 import os
#       2
# ----> 3 CUR_DIR = os.path.abspath(os.path.dirname(__file__))
#       4 CUR_DIR
#
# NameError: name '__file__' is not defined

# %%
f"{CUR_DIR}/scripts"
# Out:
# '/Users/user1/airflow/dags/scripts'

# %% [markdown]
# INSERT INTO stations (id, flow_99, flow_max, flow_median, flow_total, n_obs) VALUES (313979.0,50.0,71.0,24.0,18447830.0,806622.0) INSERT INTO stations (id, flow_99, flow_max, flow_median, flow_total, n_obs) VALUES (313980.0,11.0,25.0,1.0,1618489.0,806622.0);
